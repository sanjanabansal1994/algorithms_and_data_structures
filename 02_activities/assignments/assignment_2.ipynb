# %% [markdown]
# # Practice Interview
#
# ## Objective
#
# _*The partner assignment aims to provide participants with the opportunity to practice coding in an interview context. You will analyze your partner's Assignment 1. Moreover, code reviews are common practice in a software development team. This assignment should give you a taste of the code review process.*_
#
# ## Group Size
#
# Each group should have 2 people. You will be assigned a partner
#
# ## Part 1:
#
# You and your partner must share each other's Assignment 1 submission.

# %% [markdown]
# ## Part 2:
#
# Create a Jupyter Notebook, create 6 of the following headings, and complete the following for your partner's assignment 1:
#
# -   Paraphrase the problem in your own words.

# %%
# Your answer here
# my partner Stephen Fong was assigned question 2 for first assignment. 
# Question was for Given the `root` of a binary tree, return all root to leaf paths in any order.

# %% [markdown]
# -   Create 1 new example that demonstrates you understand the problem. Trace/walkthrough 1 example that your partner made and explain it.

# %%
# Your answer here
# My partner used this example to show his work

class TreeNode(object):
  def __init__(self, val = 0, left = None, right = None):
    self.val = val
    self.left = left
    self.right = right

root4 = TreeNode(6)
root4.left = TreeNode(8)
root4.right = TreeNode(2)
root4.left.left = TreeNode(3)
root4.left.right = TreeNode(5)
root4.right.left = TreeNode(7)
root4.right.right = TreeNode(0)

# Based on this example my partner used the answe should be something like this:
# [[6,8,3],[6,8,5],[6,2,7],[6,2,0]]

#My new example
root2 = TreeNode(0)
root2.left = TreeNode(1)
root2.right = TreeNode(2)
root2.left.left = TreeNode(3)
root2.left.right = TreeNode(4)
root2.left.left.left = TreeNode(5)
root2.right.right = TreeNode(0)

#It's answer should be
#[[0,1,3,5],[0,1,4],[0,2,0]]

# %% [markdown]
# -   Copy the solution your partner wrote.

# %%
# Your answer here
from typing import List

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

def bt_path(root: TreeNode) -> List[List[int]]:
    paths = []

    if not root:
        return []

    def dfs(node, path):
        path.append(node.val)
        if not node.left and not node.right:
            paths.append(path)
        if node.left:
            dfs(node.left, path.copy())
        if node.right:
            dfs(node.right, path.copy())

    
    dfs(root, [])
    return paths

root1 = TreeNode(1)
root1.left = TreeNode(2)
root1.right = TreeNode(2)
root1.left.left = TreeNode(3)
root1.left.right = TreeNode(5)
root1.right.left = TreeNode(6)
root1.right.right = TreeNode(7)

print(bt_path(root1))
print(bt_path(root4))
print(bt_path(root2))
# Out:
# [[1, 2, 3], [1, 2, 5], [1, 2, 6], [1, 2, 7]]
# [[6, 8, 3], [6, 8, 5], [6, 2, 7], [6, 2, 0]]
# [[0, 1, 3, 5], [0, 1, 4], [0, 2, 0]]

# %% [markdown]
# -   Explain why their solution works in your own words.

# %%
# Your answer here
#My partner has taken care for the case where root is empty and coded the solution correctly, as it is producing the expected results

# %% [markdown]
# -   Explain the problem’s time and space complexity in your own words.

# %%
# Your answer here
# As my partner calculated
#Time complexity: O(N), N is the total number of tree nodes. Each node is visited once.
#Space Complexity: O(N). In the worst case scenario, the maxinum nuumber of paths will be the maximum number of tree nodes , or N. 
# Worst case scenario could be when there is depth of one and each node is separated path expected in output

# %% [markdown]
# -   Critique your partner's solution, including explanation, and if there is anything that should be adjusted.

# %%
# Your answer here
# I can not think of any better solution he has taken the copy of previous path to use in future traversing of tree which help in time complexity.

# %% [markdown]
# ## Part 3:
#
# Please write a 200 word reflection documenting your process from assignment 1, and your presentation and review experience with your partner at the bottom of the Jupyter Notebook under a new heading "Reflection." Again, export this Notebook as pdf.

# %% [markdown]
# ### Reflection

# %% [markdown]
# # Your answer here:
# I learnt various different data structures and algorithms. I had worked on question3 for my assignment1 to find out the missing number in given list that is supposed to be of range(n). Honestly I liked solution given by my partner and he has taken care of edge cases and is the best in term of handling time and space complexity. I would like to has critique on mine as well if that's possible. I learnt how to calculate the complexity of various different algorithms. I feel there is lot to learn in this module and it needs more practice for me. I also think judging another person's solution gives you more challenging job and is more effective learning.

# %% [markdown]
# ## Evaluation Criteria
#
# We are looking for the similar points as Assignment 1
#
# -   Problem is accurately stated
#
# -   New example is correct and easily understandable
#
# -   Correctness, time, and space complexity of the coding solution
#
# -   Clarity in explaining why the solution works, its time and space complexity
#
# -   Quality of critique of your partner's assignment, if necessary

# %% [markdown]
# ## Submission Information
#
# 🚨 **Please review our [Assignment Submission Guide](https://github.com/UofT-DSI/onboarding/blob/main/onboarding_documents/submissions.md)** 🚨 for detailed instructions on how to format, branch, and submit your work. Following these guidelines is crucial for your submissions to be evaluated correctly.
#
# ### Submission Parameters:
# * Submission Due Date: `HH:MM AM/PM - DD/MM/YYYY`
# * The branch name for your repo should be: `assignment-2`
# * What to submit for this assignment:
#     * This Jupyter Notebook (assignment_2.ipynb) should be populated and should be the only change in your pull request.
# * What the pull request link should look like for this assignment: `https://github.com/<your_github_username>/algorithms_and_data_structures/pull/<pr_id>`
#     * Open a private window in your browser. Copy and paste the link to your pull request into the address bar. Make sure you can see your pull request properly. This helps the technical facilitator and learning support staff review your submission easily.
#
# Checklist:
# - [ ] Created a branch with the correct naming convention.
# - [ ] Ensured that the repository is public.
# - [ ] Reviewed the PR description guidelines and adhered to them.
# - [ ] Verify that the link is accessible in a private browser window.
#
# If you encounter any difficulties or have questions, please don't hesitate to reach out to our team via our Slack at `#cohort-3-help`. Our Technical Facilitators and Learning Support staff are here to help you navigate any challenges.
